# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
#plt.style.use('seaborn-whitegrid')
import numpy as np
from IPython.core.pylabtools import figsize # import figsize
#figsize(12.5, 4) # 设置 figsize
plt.rcParams['savefig.dpi'] = 200 #图片像素
plt.rcParams['figure.dpi'] = 200 #分辨率

# %%
ELife = ([300, 450, 600, 1100])
EEE = ([30, 50, 72.7, 95])
SEG_res = ([0.20,0.25, 0.4, 0.6, 0.8])

B8_ELife_1sigma = ([0.08627860797385499,0.11774125662019201,0.162437958617304,0.2245025586999])
ER_ELife_1sigma = ([0.422040288,0.017593536,0.002864064,0])
NR_ELife_1sigma = ([0.0168867302268,0.008954277038,0.0079467383604,0.005967018778])

B8_ELife_err_1sigma = ([8.349897846020902e-05,9.754251089702085e-05,0.00011457064525483768,0.00013469151723744278])
ER_ELife_err_1sigma = ([0.009291849647910527,0.0018971505037160335,0.000765449559899279,0])
NR_ELife_err_1sigma = ([3.650700674840205e-05,2.658390075282965e-05,2.504366585907234e-05,2.17011198611353e-05])

B8_EEE_1sigma = ([0.054110799855804,0.11182560877213199,0.162437958617304,0.196679753820792])
ER_EEE_1sigma = ([0.104742912,0.015956928,0.002864064,0.000613728])
NR_EEE_1sigma = ([0.0088644619812,0.0091801563812,0.0079467383604,0.0068579872984])

B8_EEE_err_1sigma = ([6.612589670067e-05,6.721794565704287e-05,0.00011457064525483768,0.0001260693244152954])
ER_EEE_err_1sigma = ([0.004629003832359615,0.0018067574792290193,0.000765449559899279,0.000354334293958403])
NR_EEE_err_1sigma = ([2.6450241050308717e-05,2.6917113332734554e-05,2.504366585907234e-05,2.3264931685779832e-05])

B8_SEG_res_1sigma = ([0.1634599196844,0.162437958617304,0.16062504650172002,0.15743981178748798,0.153793765937184])
ER_SEG_res_1sigma = ([0.002659488,0.002864064,0.004296096,0.007978464,0.019025568])
NR_SEG_res_1sigma = ([0.0078266955648,0.0079467383604,0.008363849586400001,0.0090496167468,0.0097667955])

B8_SEG_res_err_1sigma = ([0.00011493048465826946,0.00011457064525483768,0.00011279422860569568,0.00011148053414248859,0.00011148051422666342])
ER_SEG_res_err_1sigma = ([0.0007376056521780456,0.000765449559899279,0.0009374804227955908,0.0012775704655223524,0.001972849854430134])
NR_SEG_res_err_1sigma = ([2.4853792267540368e-05,2.504366585907234e-05,2.5692510955864144e-05,2.67250506506114e-05,2.7763837294650034e-05])


#B8_ELife_2sigma = ([0.061757319391812,0.13871407286632498,0.16449146145467997,0.2388793509078,0.313643280536625])
#ER_ELife_2sigma = ([0.038460288,0.000818304,0.079989216,0.015956928,0.0010228799999999999])
#NR_ELife_2sigma = ([0.006964613082,0.0195942043248,0.0198099025236,0.018902517894400003,0.0154454274436])

#B8_ELife_err_2sigma = ([7.06437615575572e-05,0.00010587413113148825,0.00011529255856101507,0.00013893731528849014,0.00015920165982977712])
#ER_ELife_err_2sigma = ([0.002804991079754087,0.00040915,0.004045208755351817,0.0018067574792290193,0.00045744360649701947])
#NR_ELife_err_2sigma = ([2.3445091960547633e-05,3.932486674419617e-05,3.95407236e-05,3.8624535742070324e-05,3.49143056266011e-05])

#B8_EEE_2sigma = ([,,0.2388793509078,])
#ER_EEE_2sigma = ([,,0.015956928,])
#NR_EEE_2sigma = ([,,0.018902517894400003,])

#B8_EEE_err_2sigma = ([,,0.00013893731528849014,])
#ER_EEE_err_2sigma = ([,,0.0018067574792290193,])
#NR_EEE_err_2sigma = ([,,3.8624535742070324e-05,])

#B8_SEG_res_2sigma = ([,0.2388793509078,,])
#ER_SEG_res_2sigma = ([,0.015956928,,])
#NR_SEG_res_2sigma = ([,0.018902517894400003,,])

#B8_SEG_res_err_2sigma = ([,0.00013893731528849014,,])
#ER_SEG_res_err_2sigma = ([,0.0018067574792290193,,])
#NR_SEG_res_err_2sigma = ([,3.8624535742070324e-05,,])

# %%
plt.yscale("log")
plt.grid(True)
plt.xlabel("Electron life time (microsec)")
plt.ylabel("Event Rate (counts/year/ton)")
x_coordinates = [600, 600]
y_coordinates = [0., 1.]
plt.plot(x_coordinates, y_coordinates,linestyle = "dotted",color = "orange")
plt.errorbar(ELife, B8_ELife_1sigma, yerr=B8_ELife_err_1sigma,color='black',linewidth = 1.,fmt = '.', capsize = 2,label = 'Boron-8')
plt.errorbar(ELife, ER_ELife_1sigma, yerr=ER_ELife_err_1sigma,color='blue',linewidth = 1., fmt = '.', capsize = 2, label = 'ER')
plt.errorbar(ELife, NR_ELife_1sigma, yerr=NR_ELife_err_1sigma,color='red',linewidth = 1., fmt = '.', capsize = 2, label = 'NR')
plt.ylim(0.001,1.)
plt.legend()
plt.show()

# %%
plt.yscale("log")
plt.grid(True)
plt.xlabel("Electron Extraction Efficiency (%)")
plt.ylabel("Event Rate (counts/year/ton)")
x_coordinates = [72.7, 72.7]
y_coordinates = [0., 1.]
plt.plot(x_coordinates, y_coordinates,linestyle = "dotted",color = "orange")
plt.errorbar(EEE, B8_EEE_1sigma, yerr=B8_EEE_err_1sigma,color='black',linewidth = 1.,fmt = '.', capsize = 2,label = 'Boron-8')
plt.errorbar(EEE, ER_EEE_1sigma, yerr=ER_EEE_err_1sigma,color='blue',linewidth = 1., fmt = '.', capsize = 2, label = 'ER')
plt.errorbar(EEE, NR_EEE_1sigma, yerr=NR_EEE_err_1sigma,color='red',linewidth = 1., fmt = '.', capsize = 2, label = 'NR')
plt.ylim(0.0001,1.)
plt.legend()
plt.show()

# %%
plt.yscale("log")
plt.grid(True)
plt.xlabel("SEG resolution")
plt.ylabel("Event Rate (counts/year/ton)")
x_coordinates = [0.25, 0.25]
y_coordinates = [0., 1.]
plt.plot(x_coordinates, y_coordinates,linestyle = "dotted",color = "orange")
plt.errorbar(SEG_res, B8_SEG_res_1sigma, yerr=B8_SEG_res_err_1sigma,color='black',linewidth = 1.,fmt = '.', capsize = 2,label = 'Boron-8')
plt.errorbar(SEG_res, ER_SEG_res_1sigma, yerr=ER_SEG_res_err_1sigma,color='blue',linewidth = 1., fmt = '.', capsize = 2, label = 'ER')
plt.errorbar(SEG_res, NR_SEG_res_1sigma, yerr=NR_SEG_res_err_1sigma,color='red',linewidth = 1., fmt = '.', capsize = 2, label = 'NR')
plt.ylim(0,1.)
plt.legend()
plt.show()
# Out:
# /Users/yunshan/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   # This is added back by InteractiveShellApp.init_path()
