# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
#plt.style.use('seaborn-whitegrid')
import numpy as np
from IPython.core.pylabtools import figsize # import figsize
#figsize(12.5, 4) # 设置 figsize
plt.rcParams['savefig.dpi'] = 200 #图片像素
plt.rcParams['figure.dpi'] = 200 #分辨率

# %%
ELife = ([300, 400, 500, 600, 800, 1100])
EEE = ([30, 40, 50, 60, 70, 80, 90])
SEG_res = ([0.2, 0.4, 0.6, 0.8])

B8_ELife_1sigma = ([0.064422561763968, 0.103508835976854, 0.13992047135869198, 0.16822441889311202, 0.204542007260952, 0.230846762003508])
ER_ELife_1sigma = ([0.040710624, 0.036414527999999995, 0.01125168, 0.00306864, 0.000409152, 0.0])
NR_ELife_1sigma = ([0.0072361891896, 0.0092740754652, 0.008975191792, 0.0083284918136, 0.007143690730400001, 0.00628626474])

B8_ELife_err_1sigma = ([7.215203636300443e-05, 6.467006717009809e-05, 0.00010633352894537735, 0.00011659343996937219, 0.00012856443758111938, 0.00013658137832832585])
ER_ELife_err_1sigma = ([0.0028858855130401485, 0.0027293709259186448, 0.0015171688054975952, 0.0007923155680503824,0.00028931273952247593, 0.0])
NR_ELife_err_1sigma = ([2.389782628450367e-05, 2.7054452912325888e-05, 2.6614929023296138e-05, 2.5638146510616577e-05,2.374459495821728e-05, 2.227408008950906e-05])

B8_EEE_1sigma = ([0.057232182609612006, 0.08823145766965801, 0.116833261960944, 0.141774650963328, 0.163073785668996, 0.181030913162076, 0.196208941775256])
ER_EEE_1sigma = ([0.10351545599999999, 0.043779264, 0.019639296, 0.008387616, 0.0040915199999999995, 0.0020457599999999998, 0.000613728])
NR_EEE_1sigma = ([0.009022703799200001, 0.0094945880036, 0.009358208022800001, 0.0090196257788, 0.00845271756, 0.007854160977600002, 0.0073440777507999995])

B8_EEE_err_1sigma = ([4.8087782862603854e-05, 5.9707147979457304e-05, 9.716566977320604e-05, 0.00010703575847458864, 0.00011479465683884129, 0.00012095002669955423, 0.000125918341614804])
ER_EEE_err_1sigma = ([0.004601800831875495, 0.0029926742478509085, 0.0020044174565194747, 0.001309919140872825, 0.0009148872129940389, 0.0006469229523289462,0.000354334293958403])
NR_EEE_err_1sigma = ([2.6685281815385446e-05, 2.7374204385898145e-05, 2.717689214587014e-05, 2.668072969608777e-05, 2.5828644943519902e-05, 2.489736249749582e-05, 2.4075320450059204e-05])

B8_SEG_res_1sigma = ([0.16924978686343198, 0.166391697283782, 0.16314384698529602, 0.15936300865743602])
ER_SEG_res_1sigma = ([0.00306864, 0.006546432, 0.0102288, 0.020662176])
NR_SEG_res_1sigma = ([0.0081445998256, 0.008742367172, 0.009328532749200001, 0.010044606572])

B8_SEG_res_err_1sigma = ([0.00011694823257180243, 8.199368886272714e-05, 8.118951538422337e-05, 8.024322223807402e-05])
ER_SEG_res_err_1sigma = ([0.0007923155680503824, 0.0011572509580899037, 0.0014465636976123796, 0.002055953305190806])
NR_SEG_res_err_1sigma = ([2.53535232028159e-05, 2.626745305004007e-05, 2.7133768394470406e-05, 2.81559320791534e-05])

# %%
plt.yscale("log")
plt.grid(True)
plt.xlabel("Electron life time (microsec)")
plt.ylabel("Event Rate (counts/year/ton)")
x_coordinates = [600, 600]
y_coordinates = [0., 1.]
plt.plot(x_coordinates, y_coordinates,linestyle = "dotted",color = "orange")
plt.errorbar(ELife, B8_ELife_1sigma, yerr=B8_ELife_err_1sigma,color='black',linewidth = 1.,fmt = '.', capsize = 2,label = 'Boron-8')
plt.errorbar(ELife, ER_ELife_1sigma, yerr=ER_ELife_err_1sigma,color='blue',linewidth = 1., fmt = '.', capsize = 2, label = 'ER')
plt.errorbar(ELife, NR_ELife_1sigma, yerr=NR_ELife_err_1sigma,color='red',linewidth = 1., fmt = '.', capsize = 2, label = 'NR')
plt.ylim(0.001,1.)
plt.legend()
plt.savefig('./rates/ELife' +  '.pdf')
plt.show()

# %%
plt.yscale("log")
plt.grid(True)
plt.xlabel("Electron Extraction Efficiency (%)")
plt.ylabel("Event Rate (counts/year/ton)")
x_coordinates = [72.7, 72.7]
y_coordinates = [0., 1.]
plt.plot(x_coordinates, y_coordinates,linestyle = "dotted",color = "orange")
plt.errorbar(EEE, B8_EEE_1sigma, yerr=B8_EEE_err_1sigma,color='black',linewidth = 1.,fmt = '.', capsize = 2,label = 'Boron-8')
plt.errorbar(EEE, ER_EEE_1sigma, yerr=ER_EEE_err_1sigma,color='blue',linewidth = 1., fmt = '.', capsize = 2, label = 'ER')
plt.errorbar(EEE, NR_EEE_1sigma, yerr=NR_EEE_err_1sigma,color='red',linewidth = 1., fmt = '.', capsize = 2, label = 'NR')
plt.ylim(0.0001,1.)
plt.legend()
plt.savefig('./rates/EEE' +  '.pdf')
plt.show()

# %%
plt.yscale("log")
plt.grid(True)
plt.xlabel("SEG resolution")
plt.ylabel("Event Rate (counts/year/ton)")
x_coordinates = [0.25, 0.25]
y_coordinates = [0., 1.]
plt.plot(x_coordinates, y_coordinates,linestyle = "dotted",color = "orange")
plt.errorbar(SEG_res, B8_SEG_res_1sigma, yerr=B8_SEG_res_err_1sigma,color='black',linewidth = 1.,fmt = '.', capsize = 2,label = 'Boron-8')
plt.errorbar(SEG_res, ER_SEG_res_1sigma, yerr=ER_SEG_res_err_1sigma,color='blue',linewidth = 1., fmt = '.', capsize = 2, label = 'ER')
plt.errorbar(SEG_res, NR_SEG_res_1sigma, yerr=NR_SEG_res_err_1sigma,color='red',linewidth = 1., fmt = '.', capsize = 2, label = 'NR')
plt.ylim(0,1.)
plt.legend()
plt.savefig('./rates/SEGreso' +  '.pdf')
plt.show()
# Out:
# /Users/yunshan/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   # This is added back by InteractiveShellApp.init_path()
