# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
#plt.style.use('seaborn-whitegrid')
import numpy as np
from IPython.core.pylabtools import figsize # import figsize
#figsize(12.5, 4) # 设置 figsize
plt.rcParams['savefig.dpi'] = 200 #图片像素
plt.rcParams['figure.dpi'] = 200 #分辨率

# %%
ELife = ([300, 400, 500, 600, 700, 800, 900, 1000, 1100])
EEE = ([30, 40, 50, 60, 70, 75, 80, 85, 90, 95])
SEG_res = ([0.20, 0.24, 0.26, 0.32, 0.36, 0.40])

B8_ELife = ([0.163849,0.262392,0.357341,0.431207,0.489827,0.53241,0.56395,0.587449,0.608787])
ER_ELife = ([0.180436,0.0957417,0.0368237,0.0171844,0.0118654,0.0102288,0.00920593,0.00961508,0.00736475])
NR_ELife = ([0.022051,0.0246788,0.0234508,0.0222953,0.021316,0.0201838,0.0191479,0.0181626,0.0176612])

B8_ELife_err = ([0.00129526,0.00163912,0.00191283,0.00210125,0.00223953,0.00233485,0.00240301,0.00245256,0.00249671])
ER_ELife_err = ([0.00607561,0.00442566,0.00274468,0.00187497,0.00155801,0.00144657,0.00137234,0.0014025,0.00122746])
NR_ELife_err = ([4.17174e-05,4.41332e-05,4.30212e-05,4.19479e-05,4.10163e-05,3.99121e-05,3.88744e-05,3.7861e-05,3.73348e-05])


B8_EEE = ([0.142029,0.221138,0.293356,0.359553,0.418961,0.443024,0.466932,0.490831,0.512098,0.527928])
ER_EEE = ([0.315866,0.127042,0.0580997,0.0310956,0.0182073,0.0165707,0.0143203,0.0116608,0.00879678,0.00593271])
NR_EEE = ([0.0254881,0.025868,0.0250973,0.0239279,0.0227836,0.0219861,0.0213019,0.0207086,0.0200841,0.0193879])

B8_EEE_err = ([0.00120593,0.00150476,0.00173313,0.00191874,0.0020712,0.00212985,0.00218656,0.00224182,0.00228987,0.002325])
ER_EEE_err = ([0.00803857,0.00509801,0.00344758,0.00252219,0.00192997,0.00184119,0.00171161,0.00154452,0.0013415,0.00110168])
NR_EEE_err = ([4.4851e-05,4.5184e-05,4.45058e-05,4.34566e-05,4.24047e-05,4.1656e-05,4.10027e-05,4.04277e-05,3.98134e-05,3.91173e-05])


B8_SEG_res = ([0.43389,0.431586,0.43131,0.430736,0.428576,0.428023])
ER_SEG_res = ([0.0139112,0.0169798,0.0177981,0.0198439,0.0222988,0.0208668])
NR_SEG_res = ([0.0220265,0.0222677,0.0226022,0.0229025,0.02318,0.0236729])

B8_SEG_res_err = ([0.00210778,0.00210217,0.0021015,0.0021001,0.00209483,0.00209348])
ER_SEG_res_err = ([0.00168698,0.00186378,0.00190816,0.00201484,0.00213584,0.00206612])
NR_SEG_res_err = ([4.16942e-05,4.19219e-05,4.22356e-05,4.25153e-05,4.27721e-05,4.32244e-05])

# %%
plt.yscale("log")
plt.grid(True)
plt.xlabel("Electron life time (microsec)")
plt.ylabel("Event Rate (counts/year/ton)")
x_coordinates = [600, 600]
y_coordinates = [0., 1.]
plt.plot(x_coordinates, y_coordinates,linestyle = "dotted",color = "red")
plt.errorbar(ELife, B8_ELife, yerr=B8_ELife_err,color='black',linewidth = 1.,fmt = '.', capsize = 2,label = 'Boron-8')
plt.errorbar(ELife, ER_ELife, yerr=ER_ELife_err,color='blue',linewidth = 1., fmt = '.', capsize = 2, label = 'ER')
plt.errorbar(ELife, NR_ELife, yerr=NR_ELife_err,color='red',linewidth = 1., fmt = '.', capsize = 2, label = 'NR')
plt.ylim(0.001,1.)
plt.legend()
plt.show()

# %%
plt.yscale("log")
plt.grid(True)
plt.xlabel("Electron extraction efficiency")
plt.ylabel("Event Rate (counts/year/ton)")
x_coordinates = [72.7, 72.7]
y_coordinates = [0., 1.]
plt.plot(x_coordinates, y_coordinates,linestyle = "dotted",color = "red")
plt.errorbar(EEE, B8_EEE, yerr=B8_EEE_err,color='black',linewidth = 1.,fmt = '.', capsize = 2,label = 'Boron-8')
plt.errorbar(EEE, ER_EEE, yerr=ER_EEE_err,color='blue',linewidth = 1., fmt = '.', capsize = 2, label = 'ER')
plt.errorbar(EEE, NR_EEE, yerr=NR_EEE_err,color='red',linewidth = 1., fmt = '.', capsize = 2, label = 'NR')
plt.ylim(0.001,1.)
plt.legend()
plt.show()

# %%
plt.yscale("log")
plt.grid(True)
plt.xlabel("SEG resolution")
plt.ylabel("Event Rate (counts/year/ton)")
x_coordinates = [0.25, 0.25]
y_coordinates = [0., 1.]
plt.plot(x_coordinates, y_coordinates,linestyle = "dotted",color = "red")
plt.errorbar(SEG_res, B8_SEG_res, yerr=B8_SEG_res_err,color='black',linewidth = 1.,fmt = '.', capsize = 2,label = 'Boron-8')
plt.errorbar(SEG_res, ER_SEG_res, yerr=ER_SEG_res_err,color='blue',linewidth = 1., fmt = '.', capsize = 2, label = 'ER')
plt.errorbar(SEG_res, NR_SEG_res, yerr=NR_SEG_res_err,color='red',linewidth = 1., fmt = '.', capsize = 2, label = 'NR')
plt.ylim(0.01,1.)
plt.legend()
plt.show()
