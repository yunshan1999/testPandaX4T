# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
#plt.style.use('seaborn-whitegrid')
import numpy as np
from IPython.core.pylabtools import figsize # import figsize
#figsize(12.5, 4) # 设置 figsize
plt.rcParams['savefig.dpi'] = 200 #图片像素
plt.rcParams['figure.dpi'] = 200 #分辨率

# %%
ELife = ([300, 400, 500, 600, 700, 800, 1100])
EEE = ([30, 40, 50, 60, 70, 80, 90])
SEG_res = ([0.2, 0.4, 0.6, 0.8])

LR_ELife = ([1.8923152757182329,0.8125612710635036,0.3733399570536786,0.23458373385448836,0.15056604013827904,0.10865491907125598,0.0658861474640199])
LR_EEE = ([1.6388922243436042,0.9330898360780975,0.5381257890995513,0.3675095060261417,0.25039441282101604,0.16786681479642238,0.12902855075247205])
LR_SEG_res = ([0.21176856529922403,0.2560268716862657,0.3763299116734304,0.5308456716373566])

LR_err_ELife = ([0.014208270692170998,0.00928595941149,0.006293539601823767,0.004988881624611841,0.003997018865217261,0.0033954647261173194,0.0026439200001644784])
LR_err_EEE = ([0.013192013048218447,0.009950159340246824,0.007556041101413688,0.006244242857798604,0.005154282067685089,0.004220470499888018,0.003700147607064413])
LR_err_SEG_res = ([0.004740032427561711,0.005212030322888726,0.006318848311529099,0.00750504218342156])

# %%
ELife_old = ([300, 400, 500, 600, 700, 800, 1100])
EEE_old = ([30, 40, 50, 60, 70, 80, 90])
SEG_res_old = ([0.2, 0.4, 0.6, 0.8])

LR_ELife_old = ([2.21193,0.942134,0.476674,0.285511,0.203938,0.162027,0.104824])
LR_EEE_old = [1.89162,1.07347,0.672127,0.445701,0.320738,0.241401,0.181128]
LR_SEG_res_old = ([0.276488,0.331891, 0.449007,0.650639])

LR_err_ELife_old = ([0.0153614,0.00999896,0.00711138,0.00550383,0.00465181,0.00414637,0.00333489])
LR_err_EEE_old = ([0.0141727,0.0106724,0.00844458,0.0068765,0.00583352,0.00506113,0.00438398,])
LR_err_SEG_res_old = ([0.00541612,0.00593419,0.00690208,0.00830881])

# %%
#plt.yscale("log")
plt.grid(True)
plt.xlabel("Electron life time (microsec)")
plt.ylabel("Leakage Ratio (%)")
x_coordinates = [600, 600]
y_coordinates = [0., 3.]
plt.plot(x_coordinates, y_coordinates,linestyle = "dotted",color = "red")
#plt.errorbar(ELife, LR_ELife, yerr=LR_err_ELife,color='black',linewidth = 1.,fmt = '.', capsize = 2,label = 'new')
plt.errorbar(ELife_old, LR_ELife_old, yerr=LR_err_ELife_old,color='black',linewidth = 1.,fmt = '.', capsize = 2, label = 'old')
plt.ylim(0.01,2.5)
#plt.legend()
plt.savefig('./leakage ratio/ELife.pdf')

# %%
#plt.yscale("log")
plt.grid(True)
plt.xlabel(" Electron Extraction Efficiency(%)")
plt.ylabel("Leakage Ratio (%)")
x_coordinates = [72.7, 72.7]
y_coordinates = [0., 2.4]
plt.plot(x_coordinates, y_coordinates,linestyle = "dotted",color = "red")
#plt.errorbar(EEE, LR_EEE, yerr=LR_err_EEE,color='black',linewidth = 1.,fmt = '.', capsize = 2, label = 'new')
plt.errorbar(EEE_old, LR_EEE_old, yerr=LR_err_EEE_old,color='black',linewidth = 1.,fmt = '.', capsize = 2, label = 'old')
plt.ylim(0.,2.)
#plt.legend()
plt.savefig('./leakage ratio/EEE.pdf')
plt.show()

# %%
#plt.yscale("log")
plt.grid(True)
plt.xlabel("SEG resolution")
plt.ylabel("Leakage Ratio (%)")
x_coordinates = [0.25, 0.25]
y_coordinates = [0., 1.]
plt.plot(x_coordinates, y_coordinates,linestyle = "dotted",color = "red")
#plt.errorbar(SEG_res, LR_SEG_res, yerr=LR_err_SEG_res,color='black',linewidth = 1.,fmt = '.', capsize = 2, label = 'new')
plt.errorbar(SEG_res_old, LR_SEG_res_old, yerr=LR_err_SEG_res_old,color='black',linewidth = 1.,fmt = '.', capsize = 2, label = 'old')
plt.ylim(0.01,1.0)
#plt.legend()
plt.savefig('./leakage ratio/SEG_res.pdf')
plt.show()
