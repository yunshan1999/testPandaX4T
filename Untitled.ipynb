# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
# %config InlineBackend.figure_format = 'svg'

SEG = np.array([20, 22, 24, 26, 28, 30,32])
LR1 = np.array([0.0876292, 0.0880324,0.0874936,0.0856015,0.084522,0.0838455,0.0839811])
LR1_err = np.array([3.43975e-03,3.44762e-03,3.43707e-3,3.39967e-03,3.37818e-03,3.3646e-03,3.36733e-03])

Elife = np.array([300, 400, 500, 600, 700, 800, 900, 1000, 1100])
LR2 = np.array([1.13089,0.416219,0.16703,0.084522,0.0561662,0.0445565,0.0383471,0.0356446,0.0325406])
LR2_err = np.array([0.0124079,7.49852e-03,4.74907e-03,3.37818e-03,2.75377e-03,2.45276e-03,2.27548e-03,2.19377e-03,2.09613e-03])

EEE = np.array([30, 40, 50, 60, 65, 70, 75, 80, 85, 90, 95])
LR3 = np.array([1.10358,0.53931,0.281408,0.162177,0.127595,0.0984297,0.0768239,0.0618389,0.0495476,0.041856,0.0369976])
LR3_err = np.array([0.0122168,8.53471e-03,6.16434e-03,4.6797e-03,4.15068e-03,3.64555e-03,3.22063e-03,2.88954e-03,2.58636e-03,2.37726e-03,2.23511e-03])

# %%
plt.yscale('log')
plt.errorbar(Elife, LR2, yerr=LR2_err, color='blue',ecolor='red', fmt='.k',capsize=3)
plot(600)
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
plt.xlabel("Eelectron lifetime(microsec)")
plt.ylabel("leakage ratio(%)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-ed0852f2b438> in <module>
#       1 plt.yscale('log')
#       2 plt.errorbar(Elife, LR2, yerr=LR2_err, color='blue',ecolor='red', fmt='.k',capsize=3)
# ----> 3 plot(600)
#       4 plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
#       5 plt.xlabel("Eelectron lifetime(microsec)")
#
# NameError: name 'plot' is not defined

# %%
plt.yscale('log')
plt.errorbar(EEE, LR3, yerr=LR3_err, color='black', fmt='.k',
             ecolor='red', elinewidth=3, capsize=3);
plt.grid(b=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
plt.xlabel("Eelectron Extraction Efficiency(%)")
plt.ylabel("leakage ratio(%)")
# Out:
# Text(0, 0.5, 'leakage ratio(%)')

# %%
plt.errorbar(SEG, LR1, yerr=LR1_err, color='black',ecolor='red', fmt='o',capsize=3)
plt.xlabel("SEG(phd)")
plt.ylabel("leakage ratio(%)")
# Out:
# Text(0, 0.5, 'leakage ratio(%)')
